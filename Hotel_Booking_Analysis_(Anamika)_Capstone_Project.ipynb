# %% [markdown]
# <a href="https://colab.research.google.com/github/Anamika1112/Hotal-Booking-Analysis/blob/main/Hotel_Booking_Analysis_(Anamika)_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# # **Hotel Booking Data Analysis**

# %% [markdown]
#  With the availability of internet and smartphones, the number of internet users in the world has already crossed 3 billion marks. The Internet has made various activities and tasks easier. This convenience of the internet has impacted travel and hotel industry. This has resulted in the origin of online hotel booking engine. Nowadays, when people plan for a vacation or holiday, they start it by exploring places and deals on the internet.Online Hotel Booking Engine has smoothened the process of hotel booking. The best part of online hotel booking engine is that it allows travelers to book a hotel in advance to avoid any type of inconvenience later. That’s why many hotels are integrating it with their website. Benefits of hotel booking engine: Hotel booking engine increases the revenue and profit of hotels. As everyone is using internet nowadays and the number of users is increasing exponentially. So, the numbers of people who book hotels online are also increasing. Earlier hoteliers used to give commission to agents, but hotel booking engine gives hoteliers business directly. This sums up the profit amount.
#
# add Codeadd Markdown

# %% [markdown]
# # **- Data**
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.

# %% [markdown]
# # **Topics covered and questions to answer from the data:**
#
# #1. Where do the guests come from?
# #2. Relation between deposit and cancellation
# #3. Which are the most busiest month?
# #4. Bookings by market segment
# #5. How many bookings were canceled?
# #6. Which month have the highest number of cancelations?
# #7. How lead time lead to cancellation?
# #8. In which month price of the hotel is high?
# # 9.which year have highest number of cancelation?
# # 10.Types of booking done by customers and its ratio?
# # 11. Selection of type of hotel according to family?
# # 12.Number of repeated guest and customer type?
# # 13.Relation between deposit and cancellation.
# # 14.How many days ahead usaually people book the hotels?
# # 15.Type od Deposit.
# # 16.Number of zero night stays in weekend and weekday?

# %% [markdown]
# 1.Types of hotel bookings done by customers and its ratio.
#
# 2.Selection of hotels according to family.
#
# 3.overview on repeated guest and customer type.
#
# 4.Distribution.
#
# 5.Relation between Deposit and cancellation.
#
# 6.Type of Deposit.
#
# 7.How lead time lead to cancellation.
#
# 8.How many days ahead usually people book?
#
# 9.Number of zero night stay in both weekday and weekend?
#
# 10.How many bookings were cancelled and how many were check out on the first day?
#
# 11.where do the guest come from?
#
# 12.Looking into market segment and distribution channel.
#
# 13.Overview of arrival period.
#
# 14.Busiest month of hotel booking?
#
# 15.which year have highest number of cancellation.
#
# 16.which month have highest number of cancellation.

# %% [markdown]
# # **- Goal**
# The aim is to do a complete data analysis including exploratory data analysis.

# %% [markdown]
# # **What is Exploratory Data Analysis?**

# %% [markdown]
# So According to our (wikipedia)  **Exploratory Data Analysis** refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
#
# Basically it is a good practice to understand the data first and try to gather as many insights from it. EDA is all about making sense of data in hand,before getting them dirty with it.

# %% [markdown]
# ## Import libraries and read files

# %% [markdown]
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python. Although there are other popular libraries like seaborn, I decided to stick with matplotlib for this basic project.
#
# **Numpy** provides a high-performance multidimensional array and basic tools to compute with and manipulate these arrays.
#
#  **Pandas** is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool. Used here for dataframe operations and visualization.

# %%
#importing required packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go
import numpy as np
# %matplotlib inline

# %% [markdown]
# Warnings are good but sometimes unnecessary, so to avoid this i have imported warnings

# %% [markdown]
# # Importing Dataset into notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_hotel = pd.read_csv("/content/drive/MyDrive/Team capstone project/Hotel Bookings.csv")

# %% [markdown]
# ### Basic insights of Data

# %%
df_hotel.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
df_hotel.tail()
# Out:
#              hotel  is_canceled  ...  reservation_status  reservation_status_date
# 119385  City Hotel            0  ...           Check-Out               2017-09-06
# 119386  City Hotel            0  ...           Check-Out               2017-09-07
# 119387  City Hotel            0  ...           Check-Out               2017-09-07
# 119388  City Hotel            0  ...           Check-Out               2017-09-07
# 119389  City Hotel            0  ...           Check-Out               2017-09-07
#
# [5 rows x 32 columns]

# %%
df_hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df_hotel.shape
# Out:
# (119390, 32)

# %%
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df_hotel.count()
# Out:
# hotel                             119390
# is_canceled                       119390
# lead_time                         119390
# arrival_date_year                 119390
# arrival_date_month                119390
# arrival_date_week_number          119390
# arrival_date_day_of_month         119390
# stays_in_weekend_nights           119390
# stays_in_week_nights              119390
# adults                            119390
# children                          119386
# babies                            119390
# meal                              119390
# country                           118902
# market_segment                    119390
# distribution_channel              119390
# is_repeated_guest                 119390
# previous_cancellations            119390
# previous_bookings_not_canceled    119390
# reserved_room_type                119390
# assigned_room_type                119390
# booking_changes                   119390
# deposit_type                      119390
# ...

# %%
df_hotel.describe()
# Out:
#          is_canceled  ...  total_of_special_requests
# count  119390.000000  ...              119390.000000
# mean        0.370416  ...                   0.571363
# std         0.482918  ...                   0.792798
# min         0.000000  ...                   0.000000
# 25%         0.000000  ...                   0.000000
# 50%         0.000000  ...                   0.000000
# 75%         1.000000  ...                   1.000000
# max         1.000000  ...                   5.000000
#
# [8 rows x 20 columns]

# %% [markdown]
# # Check the missing Values

# %% [markdown]
# Many real-world datasets may contain missing values for various reasons. They are often encoded as NaNs, blanks or any other placeholders.

# %%
#Let's count how many NaN or Null values we have
df_hotel.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# # **Conclusion**:Looks like we have quite alot of NaN values in company and agent. Highly doubt they have impact an on the analysis and will remove the 2 columns. The reason why we can't remove rows with NaN values is because that will mean we are removing 112593 rows out of 119390 rows. so removing columns will bw a bettter idea since thoes two attributes(agent and companies) are unimportant.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data cleaning is the process of preparing data for analysis by removing or modifying data that is incorrect, incomplete, irrelevant, duplicated, or improperly formatted.
#
# This data is usually not necessary or helpful when it comes to analyzing data because it may hinder the process or provide inaccurate results. There are several methods for cleaning data depending on how it is stored along with the answers being sought.
#
# Data cleaning is not simply about erasing information to make space for new data, but rather finding a way to maximize a data set’s accuracy without necessarily deleting information.

# %%
df_hotel = df_hotel.drop(columns = ['agent','company'])
df_hotel.shape
# Out:
# (119390, 30)

# %%
#Droping Duplicate values
duplicate_rows = df_hotel[df_hotel.duplicated()]
print("Number of duplicate rows:",duplicate_rows.shape)
# Out:
# Number of duplicate rows: (32020, 30)

# %%
df_hotel.shape
# Out:
# (119390, 30)

# %%
df_hotel.count()
# Out:
# hotel                             119390
# is_canceled                       119390
# lead_time                         119390
# arrival_date_year                 119390
# arrival_date_month                119390
# arrival_date_week_number          119390
# arrival_date_day_of_month         119390
# stays_in_weekend_nights           119390
# stays_in_week_nights              119390
# adults                            119390
# children                          119386
# babies                            119390
# meal                              119390
# country                           118902
# market_segment                    119390
# distribution_channel              119390
# is_repeated_guest                 119390
# previous_cancellations            119390
# previous_bookings_not_canceled    119390
# reserved_room_type                119390
# assigned_room_type                119390
# booking_changes                   119390
# deposit_type                      119390
# ...

# %%
df_hotel=df_hotel.drop_duplicates()
df_hotel
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0       Resort Hotel            0  ...           Check-Out               2015-07-01
# 1       Resort Hotel            0  ...           Check-Out               2015-07-01
# 2       Resort Hotel            0  ...           Check-Out               2015-07-02
# 3       Resort Hotel            0  ...           Check-Out               2015-07-02
# 4       Resort Hotel            0  ...           Check-Out               2015-07-03
# ...              ...          ...  ...                 ...                      ...
# 119385    City Hotel            0  ...           Check-Out               2017-09-06
# 119386    City Hotel            0  ...           Check-Out               2017-09-07
# 119387    City Hotel            0  ...           Check-Out               2017-09-07
# 119388    City Hotel            0  ...           Check-Out               2017-09-07
# ...

# %%
df_hotel.count()
# Out:
# hotel                             87370
# is_canceled                       87370
# lead_time                         87370
# arrival_date_year                 87370
# arrival_date_month                87370
# arrival_date_week_number          87370
# arrival_date_day_of_month         87370
# stays_in_weekend_nights           87370
# stays_in_week_nights              87370
# adults                            87370
# children                          87366
# babies                            87370
# meal                              87370
# country                           86918
# market_segment                    87370
# distribution_channel              87370
# is_repeated_guest                 87370
# previous_cancellations            87370
# previous_bookings_not_canceled    87370
# reserved_room_type                87370
# assigned_room_type                87370
# booking_changes                   87370
# deposit_type                      87370
# ...

# %% [markdown]
# **Now we will just need remove 488 rows with NaN values. 488 rows out of 119390 rows are negligible hence i will just remove**

# %%
df_hotel = df_hotel.dropna(axis=0)

#check to see if there are any more NaN data

df_hotel.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
#Cancelled and non cancelled
hotels_not_cancelled = df_hotel[df_hotel['is_canceled'] == 0]
hotels_cancelled = df_hotel[df_hotel['is_canceled'] == 1]

# %%
hotels_not_cancelled.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 30 columns]

# %%
df_hotel.is_canceled
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: is_canceled, Length: 86914, dtype: int64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# # **Type of Hotel Booking done by customers and its ratio**

# %%
# Enlarging the pie chart
plt.rcParams['figure.figsize'] = 8,8
labels = hotels_not_cancelled['hotel'].value_counts().index
numbers = hotels_not_cancelled['hotel'].value_counts()
# As the name suggest, explode will determine how much each section is seperated from each other
exp = [0,0.1]
# Determine the color of the piechart
cl = ['orange','red']
#Putting them together. Sizes with the count, explode with the magnitude of seperation between pies, colors with colors,
#autopct enables you to display ther percentage value using Python string formatting. 1% will round off to the tenth place.
plt.pie(numbers, labels=labels, colors=cl, explode=exp, autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# # it seems that huge proportion of hotel was city hotel. Resort hotel tend to be an expensive side and most people will stick to city hotels.
# # Also , resort hotels tend to be appropriate for larger group of people. ## lets have an overview of number of people who booked thge hotel.

# %%
#Looking into adults
#using groupby to group according to hotel types only
hotels_not_cancelled.groupby('hotel')['adults'].describe()
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# hotel
# City Hotel    37365.0  1.846166  0.551000  0.0  2.0  2.0  2.0  4.0
# Resort Hotel  25566.0  1.849722  0.461404  0.0  2.0  2.0  2.0  4.0

# %%
#Looking into children
#using groupby to group according to hotels types only
hotels_not_cancelled.groupby('hotel')['children'].describe()
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# hotel
# City Hotel    37365.0  0.121638  0.423590  0.0  0.0  0.0  0.0  3.0
# Resort Hotel  25566.0  0.118478  0.418996  0.0  0.0  0.0  0.0  3.0

# %% [markdown]
# # **It seems that mean value for adults are (1.872942) in city hotels and for childrens are (0.149370) which is higher for resort hotel. This means resort hotel are better choice for larger families.

# %% [markdown]
# # Overview on repeated guest

# %%
#Number of repeated guest
df_hotel["is_repeated_guest"].replace([1,0],["Yes","No"], inplace=True) #[1=yes" means guest are repeated", 0=no"means guest are not repeated]
plt.hist(df_hotel.is_repeated_guest,color="blue")
plt.xlabel('Repeated Guest')
plt.ylabel('count')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0, 0.5, 'count')

# %% [markdown]
# # Low number of repeated guest.Less than 5000 guest fall under this category. Hotel should do more advertisement work and should provide quality service to increase their repeated guest.

# %% [markdown]
# ## Type of Guest

# %%
#Plotting type of guest
hotels_not_cancelled["customer_type"]
plt.hist(df_hotel.customer_type)
plt.xlabel('Type of customers')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# # Majority of bookings are transient. This means that booking is not a part of group or contract. With ease of booking directly from the website, most people tend to skip middleman to ensure quick response from thier booking.

# %% [markdown]
# # **Number of repeated guest and customer types**

# %%
deposit = df_hotel[['customer_type','is_repeated_guest']]
pivot = pd.pivot_table(deposit, index='customer_type', columns='is_repeated_guest', aggfunc=len)

deposit = list(pivot.index)
ax= pivot.plot(kind="bar")
fig = ax.get_figure()
#Changes the plot dimension
fig.set_size_inches(15,10)
# Change the axes labels
ax.set_xlabel("customer_type")
ax.set_ylabel("count")
for p in ax.patches:
  ax.text(p.get_x(),p.get_height(), f"{int(p.get_height())}", fontsize=15)

# %% [markdown]
# # **customer_type**
# # Contract - when the booking has an allotment or other type of contract associated to it;
# # Group – when the booking is associated to a group;
# # Transient – when the booking is not part of a group or contract, and is not associated to other transient booking;
# ## Transient-party – when the booking is transient, but is associated to at least other transient booking

# %% [markdown]
# # **Conclusion**
# #As we see in this graph there are only 3415 repeated guest. 85%  repeated guest belong to transient. Hotel should do more advertisement work and give better quality service to increase their repeated guest.
# # Majority of bookings are transient(out of 87370 booking 69031 booking is of transient). This means that booking is not a part of group or contract. With ease of booking directly from the website, most people tend to skip middleman to ensure quick response from thier booking.

# %% [markdown]
# # **Distribution**

# %%
#Plotting distribution of Total, Confirmed $ Canceled booking
df_hotel_dist = pd.concat([df_hotel.hotel.value_counts(), df_hotel[df_hotel.is_canceled == 0].hotel.value_counts(), df_hotel[df_hotel.is_canceled == 1].hotel.value_counts()], axis=1)
df_hotel_dist.columns = ['Total','Confirmed','Canceled']
ax = df_hotel_dist.plot.bar(rot=0, figsize=(8,8))
for p in ax.patches:
  ax.text(p.get_x(),p.get_height(), f"{int(p.get_height())}", fontsize=15)

# %% [markdown]
# ##:> 72% confirm rate for city hotel, 79% confirm rate for resort hotel.
# ## :> 28% cancel rate for city hotel, 21% cancel rate for resort hotel.
#
# # Huge proportion of cancelation belongs to from city hotels. This was expected since 3/4th of the hotel booking belongs to city hotels.

# %% [markdown]
# ### Overview on cancelation

# %% [markdown]
# # **Relation between deposit and cancellation**

# %%
#Plotting the relation between cancelation and deposit type
deposit = df_hotel[['deposit_type','is_canceled']]
pivot = pd.pivot_table(deposit, index='deposit_type', columns='is_canceled', aggfunc=len)
pivot['total'] = pivot[0] + pivot[1]

deposit = list(pivot.index)
count_stays = list(pivot['total'])
ax= pivot.plot(kind="bar")
fig = ax.get_figure()
#Changes the plot dimension
fig.set_size_inches(15,10)
# Change the axes labels
ax.set_xlabel("deposit_type")
ax.set_ylabel("count")
for p in ax.patches:
  ax.text(p.get_x(),p.get_height(), f"{int(p.get_height())}", fontsize=15)

# using plt.show to show the plot
plt.show()

# %% [markdown]
# # Almost 23K bookings of deposit 'No_Deposit'were cancelled. These numbers are huge in the hotels were not able to replace the cancelled bookings in time. It's a significant loss for the hotel.
# # Also it is intersting to note that non_refundable deposits had more cancellation than refundable deposits. Logically one would have assumed that refundable deposit have more cancellation as hotel rates are usually higher for refundable deposit type rooms and customers pay more in anticipation of cancellation.

# %% [markdown]
# # **Type of Deposit**

# %%
sns.countplot(data = df_hotel, x = 'deposit_type', hue = 'hotel').set_title('Type of Deposit', fontsize= 20)
#Setting width and height
plt.rcParams['figure.figsize'] = (20,10)

# %% [markdown]
# # Majority of booking does not require deposit. With respect to resort hotel, city hotel prefer more 'no deposit' case while booking. This is also one of the reason of cancellation rate is higher in city hotels.

# %%
#Enlarging the plot
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(data=df_hotel, x = 'distribution_channel', hue='is_canceled')
#Rotating x_axis label
plt.xticks(rotation = 45)
plt.subplot(1,2,2)
sns.countplot(data= df_hotel, x = 'market_segment', hue = 'is_canceled')
#Rotating x-axis label
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# # Majority of Distribution channel and market segment involve in travel agencies. Booking and cancelation both are larger through travel agencies(online or offline).

# %% [markdown]
# # **Relation between lead time and cancellation rate**

# %%
#Box plot showing how lead time effects cancellation
fig = px.box(df_hotel, x='hotel', y='lead_time', color='is_canceled', notched=True)
fig.update_layout(title='Booking Cancelations by lead Time and Hotel',
                  xaxis_title='Hotel',
                  yaxis_title='Booking Lead Time(Days)')
#using this to show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="83681864-0829-4a5a-bf70-e3313ca81300" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83681864-0829-4a5a-bf70-e3313ca81300")) {
#                     Plotly.newPlot(
#                         '83681864-0829-4a5a-bf70-e3313ca81300',
# ...

# %% [markdown]
# # It is clear that booking made with larger lead times were more frequently canceled at both hotels. A possible explanation for this is thatbooking made far ahead of the arrival date provide more time for the travel plans of the guests to change..For example , someone who is booking a stay on monday for Friday of the same week may be more likely to have definitive travel plans and follow through with the booking than someone booking 6 month in advance.

# %%
hotels_cancelled.lead_time.agg(['min','mean','max'])
# Out:
# min       0.000000
# mean    105.821874
# max     629.000000
# Name: lead_time, dtype: float64

# %%
hotels_not_cancelled.lead_time.agg(['min','mean','max'])
# Out:
# min       0.000000
# mean     70.439291
# max     737.000000
# Name: lead_time, dtype: float64

# %% [markdown]
# # **How many days ahead usually people book?**

# %%
df_hotel.lead_time.agg(['min','mean','max'])
# Out:
# min       0.000000
# mean     80.202741
# max     737.000000
# Name: lead_time, dtype: float64

# %% [markdown]
# # People usually made a booking 2 months ahead
# # Extreme cases appeared to be someone booked on the same day they checked in or someone made a booking 2 years ahead

# %% [markdown]
# # **Number of zero night stay in both weekend and weekday?**

# %%
zero_night_stays = df_hotel[(df_hotel.stays_in_weekend_nights == 0) & (df_hotel.stays_in_week_nights == 0)]
zero_night_stays
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0       Resort Hotel            0  ...           Check-Out               2015-07-01
# 1       Resort Hotel            0  ...           Check-Out               2015-07-01
# 167     Resort Hotel            0  ...           Check-Out               2015-07-06
# 168     Resort Hotel            0  ...           Check-Out               2015-07-06
# 196     Resort Hotel            0  ...           Check-Out               2015-07-07
# ...              ...          ...  ...                 ...                      ...
# 115483    City Hotel            0  ...           Check-Out               2017-07-06
# 117701    City Hotel            0  ...           Check-Out               2017-08-08
# 118029    City Hotel            0  ...           Check-Out               2017-08-14
# 118631    City Hotel            0  ...           Check-Out               2017-08-23
# ...

# %% [markdown]
# # There were 642 cases that customer did not stay for a single night which meant they either canceled the booking or checked-out on the same day they checked-in
# # The case at index 1 was the extreme case that the customer booked 2 years ahead but did not stay for any night when they arrived, hmm.. interesting

# %% [markdown]
# # **How many were canceled and how many were checked out on the same day?**

# %%
zero_night_stays.is_canceled.value_counts()

# %% [markdown]
# # 617 cases were checked out on the same day they checked in
# # 25 cases were canceled bookings

# %% [markdown]
# # **Looking into from which countries visitors are from**

# %%
visitors_from_diffrent_countries = df_hotel[df_hotel['is_canceled'] == 0].groupby(['country']).size().reset_index(name ='count')

#we will be using plotly.express to plot a chloropleth map.
import plotly.express as px
px.choropleth(visitors_from_diffrent_countries,
              locations = "country",
              color ="count",
              hover_name = "country", #columns to add hover ionformation


              color_continuous_scale=px.colors.sequential.Plasma,
              title="Home country of visitors")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="70538a33-c71f-4f9e-8bbc-158510fe4895" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("70538a33-c71f-4f9e-8bbc-158510fe4895")) {
#                     Plotly.newPlot(
#                         '70538a33-c71f-4f9e-8bbc-158510fe4895',
# ...

# %% [markdown]
# # We have huge number of visitors from western Europe, namely Portugal, France and UK being the highest.
# # We should instruct our marketing group to target people from this region.

# %% [markdown]
# # **Looking into Market Segment and Distribution Channel**

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = df_hotel, x = 'market_segment').set_title('Types of market segment', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Types of market segment')

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = df_hotel, x = 'distribution_channel').set_title('Types of distribution channel', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Types of distribution channel')

# %% [markdown]
# # Majority of the distribution channel and market segments involve travel agencies(online or offline)
# # We can target our marketing area to be on these travel agencies website and work with them since majority of the visitors tend to reach out of them.

# %% [markdown]
# ## **Overview of arrival period**

# %%
lst3 = ['hotel', 'arrival_date_year', 'arrival_date_month','arrival_date_day_of_month' ]
period_arrival = df_hotel[lst3]
sns.countplot(data = period_arrival, x = 'arrival_date_year', hue = 'hotel')

# %% [markdown]
# # **Busiest month of hotel booking**

# %%
plt.figure(figsize=(20,5))

sns.countplot(data = period_arrival, x = 'arrival_date_month', hue = 'hotel', order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
          'August', 'September', 'October', 'November', 'December']).set_title('Graph showing number of arrival per month',fontsize=20),# Arranging the month in the order
plt.xlabel('Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import seaborn as sns
sns.heatmap(pd.crosstab(df_hotel.arrival_date_month,df_hotel.hotel),cmap="coolwarm")

# %% [markdown]
# #In the above graph I can see that 2016 seems to be the year where hotel booking is at its highest for both city hotel and resort hotel. we also see an increasing trend in booking around the middle of year, with August being the highest and january being the lowest . Summer ends around August, followed straight by Autumn . It seems that summer periord is peak period for hotel booking.

# %% [markdown]
# ## **Looking into price per month per hotel**

# %% [markdown]
# # average daily rate =  𝑆𝑢𝑚𝑂𝑓𝐴𝑙𝑙𝐿𝑜𝑑𝑔𝑖𝑛𝑔𝑇𝑟𝑎𝑛𝑠𝑎𝑐𝑡𝑖𝑜𝑛𝑇𝑜𝑡𝑎𝑙𝑁𝑢𝑚𝑏𝑒𝑟𝑂𝑓𝑆𝑡𝑎𝑦𝑖𝑛𝑔𝑁𝑖𝑔ℎ𝑡
# # average daily rate per person =  𝐴𝐷𝑅𝐴𝑑𝑢𝑙𝑡𝑠+𝐶ℎ𝑖𝑙𝑑𝑟𝑒𝑛
# # We will need to find out average daily rate per person

# %%
# Resizing plot 
plt.figure(figsize=(12,5))

# Calculating average daily rate per person
df_hotel['adr_pp'] = df_hotel['adr'] / (df_hotel['adults'] + df_hotel['children']) 
actual_guests =df_hotel.loc[df_hotel["is_canceled"]==0]
actual_guests['price'] = actual_guests['adr'] * (actual_guests['stays_in_weekend_nights'] + actual_guests['stays_in_week_nights'])
sns.lineplot(data = actual_guests, x = 'arrival_date_month', y = 'price', hue = 'hotel')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Seasonal effect are present for both hotel but to diffrent degree and with diffrent profiles. For City Hotels the month of May and September coincide with the highest adr while the lowest was during the middle of winter((Nov-Jan). Seasonal effects at Resort Hotel are even more pronounced with greater fluctuation in adr throughout the year than the City Hotel and a more defined peak in the month of August and dip during the winter.

# %% [markdown]
# # **Cancellation rate by months**

# %%
booking_by_month_canceled = df_hotel[df_hotel.is_canceled == 1].groupby('arrival_date_month').arrival_date_month.count().sort_values(ascending=False)
plt.figure(figsize=(10,15))
plt.title('Number of Canceled Bookings by Month')
ax = sns.barplot(booking_by_month_canceled.values,booking_by_month_canceled.index)
for p in ax.patches:
    ax.text(p.get_width(),p.get_y() + p.get_height()/2,f"{int(p.get_width())}",fontsize=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# # **Year in which booking were most canceled**

# %%
bookings_by_year_canceled = df_hotel[df_hotel.is_canceled == 1].groupby('arrival_date_year').arrival_date_year.count()
ax = sns.barplot(bookings_by_year_canceled.index,bookings_by_year_canceled.values)
plt.title('Number of Canceled Bookings')
for p in ax.patches:
  ax.text(p.get_x(),p.get_height(),f"{int(p.get_height())}",fontsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## **Confirmed Booking**

# %%
bookings_by_year_confirmed = df_hotel[df_hotel.is_canceled == 0].groupby('arrival_date_year').arrival_date_year.count()
ax = sns.barplot(bookings_by_year_confirmed.index,bookings_by_year_confirmed.values)
plt.title('Number of Confirmed Bookings')
for p in ax.patches:
  ax.text(p.get_x(),p.get_height(),f"{int(p.get_height())}",fontsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
confirmed = df_hotel.loc[df_hotel["is_canceled"]==0]

# %%
df_hotel['canceled'] = df_hotel['is_canceled'] == 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hotels_not_cancelled = df_hotel[df_hotel['is_canceled'] == 0]

# %%
hotels_pivot = pd.pivot_table(
	hotels_not_cancelled,
	values="is_canceled",
	index="arrival_date_year",
	columns="arrival_date_month",
	aggfunc=len
)

ax =hotels_pivot.plot(kind="bar")
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(14, 10)
# Change the axes labels
ax.set_xlabel("Years")
ax.set_ylabel("Bookings")

# Use this to show the plot in a new window
plt.show()
hotels_pivot
# Out:
# arrival_date_month   April  August  December  ...  November  October  September
# arrival_date_year                             ...
# 2015                   NaN  1869.0    1589.0  ...    1400.0   2239.0     2259.0
# 2016                2733.0  2973.0    2118.0  ...    2499.0   3007.0     2762.0
# 2017                2732.0  2771.0       NaN  ...       NaN      NaN        NaN
#
# [3 rows x 12 columns]

# %% [markdown]
# # **Relation between cancellation and repetaed guest**

# %%
df_hotel["is_canceled"].replace([1,0],['Yes','No'],inplace=True)
df_hotel["is_repeated_guest"].replace([1,0],['Yes','No'], inplace=True)
df=df_hotel.groupby(['is_canceled','is_repeated_guest']).size()
df.plot(kind='bar')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(df_hotel['market_segment'], df_hotel['days_in_waiting_list'])
ax.set_xlabel('Market Segment')
ax.set_ylabel('days on waiting list')
plt.show()

# %% [markdown]
# # Aviation industry has the minimum number of days on waiting list.
# # The reason for tghis might be that when the flight has to land at a location it shoulds provide immidiate accomodation to all of his working staff(like pilot, cabincrew), etc) .
# ## So they don't entertain hotels which put them on waiting list for too long.
# # In general hotel mangement sees that they make arrngement immediatelty and provide rooms to them with almost zero waiting list.

# %%
sns.countplot(data=df_hotel, x='previous_cancellations', hue='is_canceled')

# %% [markdown]
# Maximum customers have 0 previous cancellations. They are less likely to cancel the current booking. However, customers who have cancelled once earlier are more likely to cancel the current booking. This also matches with the positive correlation between previous_cancellations and is_cancelled .

# %% [markdown]
# # **Final Analysis**
# # Here's what the hotels can do to improve business in the future:
#
# # Resort hotels tend to have less bookings in comparison to city hotels so they need to work on their marketing strategy and promote the hotels more, especially on social media.
# # Resort hotels could also reduce prices to increases booking percentages.
# # May-August happens to be the busiest months but so the hotels should target more customers and try to do more business during these times.
# # Although city hotels have more bookings, they also tend to have more cancellations so to prevent this they could take advance money during vacation. This would ensure most bookings to not being cancelled. They could also apply no-refund policies or make the refund policies rather strict so the customers choose not to cancel.
# # It is quite clear most customers travel in pairs and bringing children or babies along are very rare so the hotels could advertise in ways that attract couples more and also business travellers.
# # Most guests do not return but as these customers have already visited once, advertisements should be targeted in such ways so they are bound to return the next time they visit. The customers could also be offered special benefits if they do return to stay.
